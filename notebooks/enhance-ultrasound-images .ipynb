# %% [markdown]
# # Image Denoising with Autoencoder
#
# ## Introduction
#
# Image denoising is a crucial step in image processing and computer vision, aimed at removing noise from images while preserving important details. Various methods exist for denoising images, ranging from traditional filtering techniques to advanced machine learning models. This notebook focuses on evaluating the performance of an autoencoder-based denoising approach and comparing it to several classical image filtering techniques.
#
# ### Objective
#
# The primary objectives of this notebook are:
#
# 1. **Implement and Train an Autoencoder Model**: An autoencoder is a type of neural network used for unsupervised learning tasks, including image denoising. We will train an autoencoder on noisy images and evaluate its performance in denoising.
#
# 2. **Compare Denoising Techniques**: We will compare the autoencoder's performance with several traditional filtering methods, including Median, Gaussian, Average, and Bilateral Filters. This comparison will help us understand how well the autoencoder performs relative to these classical methods.
#
# 3. **Evaluate and Visualize Results**: We will use Peak Signal-to-Noise Ratio (PSNR) to quantify the quality of denoising. PSNR is a common metric used to measure the quality of reconstructed images by comparing them to the original noisy images. Higher PSNR values indicate better image quality.
#
# ### Dataset
#
# The dataset used in this notebook is custom-made and consists of noisy images and their corresponding clean versions. As the dataset is not publicly available, the results and comparisons are specific to this dataset.
#
# ### Methods
#
# #### Autoencoder
#
# An autoencoder is a type of neural network that learns to compress and then reconstruct data. For image denoising, the autoencoder is trained to map noisy images to clean images. The architecture includes:
#
# - **Encoder**: Compresses the input image into a lower-dimensional representation.
# - **Decoder**: Reconstructs the image from the compressed representation.
#
# #### Traditional Filters
#
# We will compare the autoencoder with the following classical filters:
#
# - **Median Filter**: Replaces each pixel's value with the median value of the pixel's neighborhood.
# - **Gaussian Filter**: Applies a Gaussian function to blur the image and reduce noise.
# - **Average Filter**: Replaces each pixel's value with the average of the pixel's neighborhood.
# - **Bilateral Filter**: Preserves edges while reducing noise by considering both spatial distance and pixel intensity.
#
# ### Evaluation Metrics
#
# - **Peak Signal-to-Noise Ratio (PSNR)**: Measures the quality of the denoised image by comparing it to the original noisy image. Higher PSNR values indicate better quality.
#
# ## Conclusion
#
# Through this notebook, we aim to demonstrate the effectiveness of the autoencoder in denoising images and compare its performance against traditional filtering techniques. By visualizing and analyzing the results, we will gain insights into the strengths and limitations of different denoising methods.
#
# ---
#
# Let's proceed with loading the data, training the autoencoder model, and evaluating the results.

# %%
import numpy as np
import pandas as pd
import os
from keras.preprocessing import image
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D,MaxPool2D ,UpSampling2D, Flatten, Input,BatchNormalization , Add
from keras.optimizers import SGD, Adam, Adadelta, Adagrad
from keras import backend as K
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import cv2
from math import log10,sqrt

# %%
train_images=sorted(os.listdir('/kaggle/input/images/Images'))

# %%
train_image=[]
for im in train_images:
  img=image.load_img('/kaggle/input/images/Images/'+im,target_size=(64,64),color_mode='grayscale')
  img=image.img_to_array(img)
  img=img/255
  train_image.append(img)

train_df=np.array(train_image)

# %%
def plot_img(dataset):
  f,ax=plt.subplots(1,5)
  f.set_size_inches(40,20)
  for i in range(5,10):
    ax[i-5].imshow(dataset[i].reshape(64,64), cmap='gray')
  plt.show()

# %%
noised_images=sorted(os.listdir('/kaggle/input/noised-images/low_quality_images'))

noised_image=[]

for im in noised_images:
  img=image.load_img('/kaggle/input/noised-images/low_quality_images/'+im,target_size=(64,64),color_mode='grayscale')
  img=image.img_to_array(img)
  img=img/255
  noised_image.append(img)

noised_df=np.array(noised_image)

# %%
plot_img(train_df)

# %%
plot_img(noised_df)

# %%
xnoised=noised_df[:4000]
xtest=noised_df[4000:]

# %%
def autoencoder():
    input_img = Input(shape=(64, 64, 1), name='image_input')

    # Encoder
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)

    # Bottleneck
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)

    # Decoder
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)

    decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    # Residual Connection
    output = Add()([decoded, input_img])

    autoencoder = Model(inputs=input_img, outputs=output)
    autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    
    return autoencoder

# %%
model= autoencoder()
model.summary()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 64, 64, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64,    │      1,280 │ image_input[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 32, 32,    │     73,792 │ max_pooling2d_18… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 16, 16,    │     18,464 │ max_pooling2d_19… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 16, 16,    │     18,496 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_56[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_18    │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 32, 32,    │     73,856 │ up_sampling2d_18… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_57[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_19    │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 64, 64, 1) │      1,153 │ up_sampling2d_19… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 64, 64, 1) │          0 │ conv2d_58[0][0],  │
# │                     │                   │            │ image_input[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 188,705 (737.13 KB)
#  Trainable params: 187,873 (733.88 KB)
#  Non-trainable params: 832 (3.25 KB)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

# Define the autoencoder model (reuse the same model from previous code)
model = autoencoder()

# Use EarlyStopping and ModelCheckpoint to prevent overfitting and save the best model
early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1)
model_checkpoint = ModelCheckpoint('best_autoencoder.keras', monitor='val_loss', save_best_only=True, verbose=1)

# Train the model with validation data
history = model.fit(
    xnoised, xnoised, 
    epochs=30, 
    batch_size=32, 
    validation_data=(xtest, xtest), 
    callbacks=[early_stopping, model_checkpoint],
    verbose=1
)

# Plot the training and validation loss
def plot_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_loss(history)
# Out:
# Epoch 1/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1742
# Epoch 1: val_loss improved from inf to 0.00277, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.1707 - val_loss: 0.0028
# Epoch 2/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020
# Epoch 2: val_loss improved from 0.00277 to 0.00068, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0019 - val_loss: 6.7518e-04
# Epoch 3/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3449e-04
# Epoch 3: val_loss improved from 0.00068 to 0.00032, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 5.3077e-04 - val_loss: 3.1608e-04
# Epoch 4/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5924e-04
# Epoch 4: val_loss improved from 0.00032 to 0.00019, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 2.5795e-04 - val_loss: 1.8746e-04
# Epoch 5/30
# 124/125 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5474e-04
# Epoch 5: val_loss improved from 0.00019 to 0.00012, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.5450e-04 - val_loss: 1.1930e-04
# Epoch 6/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0415e-04
# Epoch 6: val_loss improved from 0.00012 to 0.00009, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.0380e-04 - val_loss: 8.6717e-05
# Epoch 7/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.4229e-05
# Epoch 7: val_loss improved from 0.00009 to 0.00006, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 7.4023e-05 - val_loss: 6.3025e-05
# Epoch 8/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6008e-05
# Epoch 8: val_loss improved from 0.00006 to 0.00005, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.5872e-05 - val_loss: 5.0399e-05
# Epoch 9/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3680e-05
# Epoch 9: val_loss improved from 0.00005 to 0.00004, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.3586e-05 - val_loss: 3.8604e-05
# Epoch 10/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5069e-05
# Epoch 10: val_loss improved from 0.00004 to 0.00003, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3.4999e-05 - val_loss: 3.1427e-05
# Epoch 11/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8688e-05
# Epoch 11: val_loss improved from 0.00003 to 0.00003, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.8634e-05 - val_loss: 2.6137e-05
# Epoch 12/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3801e-05
# Epoch 12: val_loss improved from 0.00003 to 0.00002, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 2.3760e-05 - val_loss: 2.2028e-05
# Epoch 13/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0030e-05
# Epoch 13: val_loss improved from 0.00002 to 0.00002, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 2.0000e-05 - val_loss: 1.8484e-05
# Epoch 14/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7046e-05
# Epoch 14: val_loss improved from 0.00002 to 0.00002, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.7021e-05 - val_loss: 1.5814e-05
# Epoch 15/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4639e-05
# Epoch 15: val_loss improved from 0.00002 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.4619e-05 - val_loss: 1.3638e-05
# Epoch 16/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2699e-05
# Epoch 16: val_loss improved from 0.00001 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.2682e-05 - val_loss: 1.1917e-05
# Epoch 17/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1115e-05
# Epoch 17: val_loss improved from 0.00001 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.1101e-05 - val_loss: 1.0468e-05
# Epoch 18/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.7469e-06
# Epoch 18: val_loss improved from 0.00001 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 9.7355e-06 - val_loss: 9.1806e-06
# Epoch 19/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.6366e-06
# Epoch 19: val_loss improved from 0.00001 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 8.6261e-06 - val_loss: 8.1270e-06
# Epoch 20/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6475e-06
# Epoch 20: val_loss improved from 0.00001 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 7.6387e-06 - val_loss: 7.3081e-06
# Epoch 21/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8235e-06
# Epoch 21: val_loss improved from 0.00001 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 6.8160e-06 - val_loss: 6.4903e-06
# Epoch 22/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.0891e-06
# Epoch 22: val_loss improved from 0.00001 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 6.0829e-06 - val_loss: 5.7989e-06
# Epoch 23/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4829e-06
# Epoch 23: val_loss improved from 0.00001 to 0.00001, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 5.4773e-06 - val_loss: 5.2722e-06
# Epoch 24/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9384e-06
# Epoch 24: val_loss improved from 0.00001 to 0.00000, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9336e-06 - val_loss: 4.6999e-06
# Epoch 25/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4735e-06
# Epoch 25: val_loss improved from 0.00000 to 0.00000, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.4688e-06 - val_loss: 4.2123e-06
# Epoch 26/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0346e-06
# Epoch 26: val_loss improved from 0.00000 to 0.00000, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.0310e-06 - val_loss: 3.8647e-06
# Epoch 27/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6644e-06
# Epoch 27: val_loss improved from 0.00000 to 0.00000, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3.6609e-06 - val_loss: 3.4995e-06
# Epoch 28/30
# 121/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3274e-06
# Epoch 28: val_loss improved from 0.00000 to 0.00000, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.3245e-06 - val_loss: 3.1567e-06
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0369e-06
# Epoch 29: val_loss improved from 0.00000 to 0.00000, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 3.0364e-06 - val_loss: 2.9167e-06
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7698e-06
# Epoch 30: val_loss improved from 0.00000 to 0.00000, saving model to best_autoencoder.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 2.7693e-06 - val_loss: 2.6326e-06

# %%
xtrain= train_df[200:]

# %%
pred = model.predict(xtest[:10])

def plot_predictions(y_true, y_pred):    
    f, ax = plt.subplots(4, 5)
    f.set_size_inches(10.5, 7.5)

    # Titles for each row
    ax[0][0].set_title('Original Noisy', fontsize=12)
    ax[1][0].set_title('Ground Truth', fontsize=12)
    ax[2][0].set_title('Predicted', fontsize=12)
    ax[3][0].set_title('Median Blurred', fontsize=12)

    for i in range(5):
        # Original noisy images
        ax[0][i].imshow(np.reshape(xtest[i], (64, 64)), aspect='auto', cmap='gray')
        ax[0][i].axis('off')

        # Ground truth images
        ax[1][i].imshow(np.reshape(y_true[i], (64, 64)), aspect='auto', cmap='gray')
        ax[1][i].axis('off')

        # Predicted images by the model
        ax[2][i].imshow(np.reshape(y_pred[i], (64, 64)), aspect='auto', cmap='gray')
        ax[2][i].axis('off')

        # Median blurred images (for comparison)
        ax[3][i].imshow(cv2.medianBlur(np.reshape(xtest[i], (64, 64)).astype(np.float32), 5), aspect='auto', cmap='gray')
        ax[3][i].axis('off')

    plt.tight_layout()
    plt.show()

plot_predictions(xtest[:5], pred[:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step

# %%
median_blur = cv2.medianBlur(xtrain[0], (5))
gaussian_blur=cv2.GaussianBlur(xtrain[0],(5,5),0)
average_blur=cv2.blur(xtrain[0],(5,5))
bilateral_filter=cv2.bilateralFilter(xtrain[0],9,75,75)
f,ax=plt.subplots(1,5)
f.set_size_inches(40,20)
ax[0].imshow(pred[0].reshape(64,64), cmap='gray')
ax[0].set_title('Autoencoder Image')
ax[1].imshow(median_blur,cmap='gray')
ax[1].set_title('Median Filter')
ax[2].imshow(gaussian_blur,cmap='gray')
ax[2].set_title('Gaussian Filter')
ax[3].imshow(average_blur,cmap='gray')
ax[3].set_title('Average Filter')
ax[4].imshow(bilateral_filter,cmap='gray')
ax[4].set_title('Bilateral Filter')
# Out:
# Text(0.5, 1.0, 'Bilateral Filter')

# %%
from math import log10, sqrt
import numpy as np

def PSNR(original, denoised):
    mse = np.mean((original - denoised) ** 2)
    if mse == 0: 
        return 100
    max_pixel = 1.0  # Since the images are normalized to [0, 1]
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

# Assuming you have already applied the different filters
median_blur = cv2.medianBlur(xtest[0], 5)
gaussian_blur = cv2.GaussianBlur(xtest[0], (5, 5), 0)
average_blur = cv2.blur(xtest[0], (5, 5))
bilateral_filter = cv2.bilateralFilter(xtest[0], 9, 75, 75)

value1 = PSNR(xtest[0], median_blur)
value2 = PSNR(xtest[0], pred[0])
value3 = PSNR(xtest[0], gaussian_blur)
value4 = PSNR(xtest[0], average_blur)
value5 = PSNR(xtest[0], bilateral_filter)

print("PSNR values")
print(f"Autoencoder Image : {value2} dB")
print(f"Median Filter Image : {value1} dB")
print(f"Gaussian Filter Image : {value3} dB")
print(f"Average Filter Image : {value4} dB")
print(f"Bilateral Filter Image : {value5} dB")
# Out:
# PSNR values
# Autoencoder Image : 51.86444780302811 dB
# Median Filter Image : 18.67381869681939 dB
# Gaussian Filter Image : 18.578237338965245 dB
# Average Filter Image : 18.759424410419644 dB
# Bilateral Filter Image : 18.95085418511154 dB

# %% [markdown]
# ## PSNR Comparison of Denoising Methods
#
# Peak Signal-to-Noise Ratio (PSNR) is a metric used to evaluate the quality of denoised images relative to the original noisy images. Higher PSNR values indicate better image quality, with less perceptual difference between the denoised image and the original.
#
# ### PSNR Values
#
# - **Autoencoder Image**: 51.86 dB
# - **Median Filter Image**: 18.67 dB
# - **Gaussian Filter Image**: 18.58 dB
# - **Average Filter Image**: 18.76 dB
# - **Bilateral Filter Image**: 18.95 dB
#
# ### Interpretation
#
# - **Autoencoder Image**: A PSNR of 51.86 dB is exceptionally high, indicating that the autoencoder model provides very high-quality denoising. The denoised image is very close to the original image, suggesting that the autoencoder effectively preserves image details and reduces noise.
#
# - **Median Filter Image**: With a PSNR of 18.67 dB, the Median Filter performs better than basic filters but is significantly lower than the autoencoder. This indicates that while the Median Filter reduces some noise, it does not achieve the same level of quality as the autoencoder.
#
# - **Gaussian Filter Image**: A PSNR of 18.58 dB is similar to the Median Filter, showing that the Gaussian Filter provides comparable denoising performance, but still falls short of the quality achieved by the autoencoder.
#
# - **Average Filter Image**: The Average Filter yields a PSNR of 18.76 dB, which is slightly better than the Median and Gaussian Filters but still much lower than the autoencoder. This suggests that the Average Filter is more effective than some other basic filters but does not match the performance of the autoencoder.
#
# - **Bilateral Filter Image**: With a PSNR of 18.95 dB, the Bilateral Filter provides the highest PSNR among the basic filters. While it performs better than the Median, Gaussian, and Average Filters, it still does not achieve the quality of the autoencoder.
#
# ### Summary
#
# The autoencoder model significantly outperforms traditional filtering methods in terms of PSNR, providing a much higher quality denoising. The high PSNR value for the autoencoder indicates that it preserves image details much better than Median, Gaussian, Average, and Bilateral Filters.
#
# In general, PSNR values above 30 dB are considered good for image quality, and values above 40 dB suggest excellent quality. The autoencoder's PSNR value well above 50 dB demonstrates exceptional denoising performance.

# %% [markdown]
# # TESTING

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing import image
from math import log10, sqrt

def load_and_preprocess_image(img_path, target_size=(64, 64)):
    img = image.load_img(img_path, target_size=target_size, color_mode='grayscale')
    img = image.img_to_array(img)
    img = img / 255.0  # Normalize the image
    return np.expand_dims(img, axis=0)  # Add batch dimension

def calculate_mse(original, denoised):
    mse = np.mean((original - denoised) ** 2)
    return mse

def calculate_psnr(original, denoised):
    mse = calculate_mse(original, denoised)
    if mse == 0:
        return 100  # Perfect match
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

def plot_single_image(original, predicted, mse, psnr):
    plt.figure(figsize=(12, 6))
    
    # Display original noisy image
    plt.subplot(1, 2, 1)
    plt.title('Original Noisy Image')
    plt.imshow(original, cmap='gray')
    plt.axis('off')
    
    # Display predicted image
    plt.subplot(1, 2, 2)
    plt.title('Denoised Image')
    plt.imshow(predicted, cmap='gray')
    plt.axis('off')
    
    plt.show()

    # Print metrics
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Peak Signal-to-Noise Ratio (PSNR): {psnr:.2f} dB")

# Load and preprocess the image
img_path = '/kaggle/input/noised-images/low_quality_images/Patient00001_Plane1_14_of_15_low_quality.png'
new_image = load_and_preprocess_image(img_path)

# Predict using the autoencoder
predicted_image = model.predict(new_image)

# Remove the batch dimension and denormalize
new_image = np.squeeze(new_image)
predicted_image = np.squeeze(predicted_image)

# Ensure images are in the correct format
new_image = (new_image * 255.0).astype(np.uint8)
predicted_image = (predicted_image * 255.0).astype(np.uint8)

# Calculate MSE and PSNR
mse = calculate_mse(new_image, predicted_image)
psnr = calculate_psnr(new_image, predicted_image)

# Plot the results and print metrics
plot_single_image(new_image, predicted_image, mse, psnr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Mean Squared Error (MSE): 3.2393
# Peak Signal-to-Noise Ratio (PSNR): 43.03 dB

# %% [markdown]
# ## Model Evaluation Metrics
#
# ### Mean Squared Error (MSE)
#
# **Value**: 3.2393
#
# **Meaning**: The Mean Squared Error (MSE) measures the average squared difference between the pixel values of the original noisy image and the denoised image produced by the autoencoder. A lower MSE value indicates that the denoised image is closer to the original noisy image, meaning the model has effectively reduced noise while preserving important image details.
#
# **Interpretation**: An MSE of 3.2393 is relatively low, suggesting that the autoencoder performs well in reconstructing the image and reducing noise. This indicates that the model's output is quite accurate.
#
# ### Peak Signal-to-Noise Ratio (PSNR)
#
# **Value**: 43.03 dB
#
# **Meaning**: The Peak Signal-to-Noise Ratio (PSNR) measures the quality of the denoised image relative to the original noisy image. It compares the maximum possible pixel value (255 for 8-bit images) to the noise or error introduced by the denoising process. Higher PSNR values generally indicate better image quality, with less perceptual difference between the original and denoised images.
#
# **Interpretation**: A PSNR of 43.03 dB is considered excellent, indicating that the denoised image is very close to the original noisy image. In general, PSNR values above 30 dB are considered good for image quality, and values above 40 dB suggest that the reconstruction is of very high quality.
#
# ### Summary
#
# - **MSE**: A lower MSE value indicates less difference between the original and denoised images, meaning the autoencoder effectively preserves details while reducing noise.
# - **PSNR**: A high PSNR value indicates that the denoised image is very close to the original noisy image, suggesting high-quality reconstruction.
#
# Overall, the obtained MSE and PSNR values suggest that the autoencoder model performs well in denoising the images, providing high-quality results with minimal noise and good preservation of original image details.
