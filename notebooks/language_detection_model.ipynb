# %% [markdown]
# # Whisper AI Language Detection

# %% [markdown]
# This notebook demonstrates the integration and application of the Whisper AI pre-trained model for detecting and recognizing multiple languages in audio inputs. It showcases how to use the Whisper model to process and classify spoken languages with high accuracy. The notebook includes examples of input handling, language detection, and result interpretation. This integration enhances the system's ability to support a multilingual user base, making it more accessible and versatile.

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-rfgbw8s8
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-rfgbw8s8
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 10.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.5 MB/s eta 0:00:00:00:01
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802821 sha256=0b6932d8b90ba5576fd055e8555b9586b3c65c40151d1322b5f4b26814157db8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-djfe3vqh/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...

# %%
 # !whisper "/kaggle/input/testets/Test.m4a" --model medium
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:06<00:00, 221MiB/s]
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:13.000]  Mr. Adolf Freeman, Mori Seth. His home contact number is 555-122-9838. His birthday is June 1, 1919.
# [00:13.000 --> 00:21.000]  He is hitched, married and as far as the offspring go, there is just one or maybe none.
# [00:21.000 --> 00:25.000]  Let's talk about his magical background now.
# [00:25.000 --> 00:34.000]  Apparently, there are a couple of important details. The one that caught my eye was his medication review, which is due.
# [00:34.000 --> 00:46.000]  It started on June 1, 1919 around 10.10 am. Oh, and same date and time is when it was noted in the medical records.
# [00:47.000 --> 01:07.000]  Hello Mr. Adolf Freeman. His home number is 555-112-9838. He was born on June 1, 1919. He is married and has four children.
# ...

# %%
# !whisper "/kaggle/input/frenchvoc/French.m4a" --model medium
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: French
# [00:00.000 --> 00:04.600]  Le cancer du sein est le cancer féminin le plus fréquent en France.
# [00:04.600 --> 00:11.720]  En 2000, il représentait 35,7% de l'ensemble des nouveaux cas de cancer chez les femmes,
# [00:11.720 --> 00:19.000]  soit environ 42 000 nouveaux cas par an et était responsable de 11 600 décès par an.

# %%
# !whisper "/kaggle/input/datasety/Hhhhh.m4a" --model medium
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: French
# [00:00.000 --> 00:05.000]  Qui crache contre l'océan lui retombe dessus.
